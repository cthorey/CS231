# %%
import matplotlib.pylab as plt
import numpy as np
from scipy.stats import norm
# %matplotlib inline

# %%
def gaussian(x,nu,sig):
    return 1/np.sqrt(2*np.pi*sig**2)*np.exp(-np.power(x-nu,2.)/2*np.power(sig,2.0))

# %%
rv = norm(loc = 5., scale = 1.0)
rv1 = norm(loc = 10., scale = 1.0)

# %%
x = np.arange(0,20,0.1)
plt.plot(x,rv.pdf(x),x,rv1.pdf(x))
